# %% [markdown]
# ## google colabの準備

# %%
# google Driveをマウント
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# カレントディレクトリを取得
# %pwd
# Out:
# '/content'

# %%
# 自動更新したいファイルがあるディレクトリに移動
# %cd "/content/gdrive/MyDrive/研究/データ分析"
# Out:
# /content/gdrive/MyDrive/研究/データ分析

# %% [markdown]
# ## MaskのIOU平均値を求める

# %%
import pandas as pd

# ファイル名を指定します
filename = "mask_iou_vales.txt"

# ファイルを読み込み、データフレームを作成します
df = pd.read_csv(filename, header=None, delimiter='\t')

# データフレームを表示します
print(df)
# Out:
#            0
# 0   0.604335
# 1   0.503017
# 2   0.326305
# 3   0.285889
# 4   0.253479
# ..       ...
# 86  0.620808
# 87  0.666144
# 88  0.561487
# 89  0.736149
# 90  0.408869
#
# [91 rows x 1 columns]

# %%
mean_value = df.mean()
print(mean_value)
# Out:
# 0    0.480342
# dtype: float64

# %%
mean_value1 = df.sum() / 100
print(mean_value1)
# Out:
# 0    0.437111
# dtype: float64

# %%
df.max()
# Out:
# 0    0.894126
# dtype: float64
